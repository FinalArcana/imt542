# %%
import requests

# Landing page
print(requests.get('https://dc13-69-72-28-217.ngrok-free.app/').text)

# List of all series ID
# print(requests.get('https://dc13-69-72-28-217.ngrok-free.app/series').text)

# Use series ID to get data for that series
# print(requests.get('https://dc13-69-72-28-217.ngrok-free.app/data/APU0000703113').text)
# Out:
# {
#   "message": "Welcome to the i7 Flask API server"
# }
#
# [
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M04",
#     "end_year": 2026,
#     "footnote_codes": NaN,
#     "item_code": "701111",
#     "item_name": "Flour, white, all purpose, per lb. (453.6 gm)",
#     "series_id": "APU0000701111",
#     "series_title": "Flour, white, all purpose, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M12",
#     "end_year": 1981,
#     "footnote_codes": NaN,
#     "item_code": "701311",
#     "item_name": "Rice, white, long grain, precooked (cost per pound/453.6 grams)",
#     "series_id": "APU0000701311",
#     "series_title": "Rice, white, long grain, precooked (cost per pound/453.6 grams) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M04",
#     "end_year": 2026,
#     "footnote_codes": NaN,
#     "item_code": "701312",
#     "item_name": "Rice, white, long grain, uncooked, per lb. (453.6 gm)",
#     "series_id": "APU0000701312",
#     "series_title": "Rice, white, long grain, uncooked, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M03",
#     "end_year": 1981,
#     "footnote_codes": NaN,
#     "item_code": "701321",
#     "item_name": "Spaghetti (cost per pound/453.6 grams)",
#     "series_id": "APU0000701321",
#     "series_title": "Spaghetti (cost per pound/453.6 grams) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1984,
#     "end_period": "M04",
#     "end_year": 2026,
#     "footnote_codes": NaN,
#     "item_code": "701322",
#     "item_name": "Spaghetti and macaroni, per lb. (453.6 gm)",
#     "series_id": "APU0000701322",
#     "series_title": "Spaghetti and macaroni, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M04",
#     "end_year": 2026,
#     "footnote_codes": NaN,
#     "item_code": "702111",
#     "item_name": "Bread, white, pan, per lb. (453.6 gm)",
#     "series_id": "APU0000702111",
#     "series_title": "Bread, white, pan, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M10",
#     "end_year": 2025,
#     "footnote_codes": NaN,
#     "item_code": "702112",
#     "item_name": "Bread, French, per lb. (453.6 gm)",
#     "series_id": "APU0000702112",
#     "series_title": "Bread, French, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M12",
#     "end_year": 1981,
#     "footnote_codes": NaN,
#     "item_code": "702211",
#     "item_name": "Bread, rye, pan (cost per pound/453.6 grams)",
#     "series_id": "APU0000702211",
#     "series_title": "Bread, rye, pan (cost per pound/453.6 grams) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M04",
#     "end_year": 2026,
#     "footnote_codes": NaN,
#     "item_code": "702212",
#     "item_name": "Bread, whole wheat, pan, per lb. (453.6 gm)",
#     "series_id": "APU0000702212",
#     "series_title": "Bread, whole wheat, pan, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M12",
#     "end_year": 1981,
#     "footnote_codes": NaN,
#     "item_code": "702213",
#     "item_name": "Bread, wheat blend, pan (cost per pound/453.6 grams)",
#     "series_id": "APU0000702213",
#     "series_title": "Bread, wheat blend, pan (cost per pound/453.6 grams) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M09",
#     "end_year": 1984,
#     "footnote_codes": NaN,
#     "item_code": "702221",
#     "item_name": "Rolls, hamburger (cost per pound/453.6 grams)",
#     "series_id": "APU0000702221",
#     "series_title": "Rolls, hamburger (cost per pound/453.6 grams) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M12",
#     "end_year": 1986,
#     "footnote_codes": NaN,
#     "item_code": "702411",
#     "item_name": "Cupcakes, chocolate (cost per pound/453.6 grams)",
#     "series_id": "APU0000702411",
#     "series_title": "Cupcakes, chocolate (cost per pound/453.6 grams) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M04",
#     "end_year": 2026,
#     "footnote_codes": NaN,
#     "item_code": "702421",
#     "item_name": "Cookies, chocolate chip, per lb. (453.6 gm)",
#     "series_id": "APU0000702421",
#     "series_title": "Cookies, chocolate chip, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M10",
#     "end_year": 2000,
#     "footnote_codes": NaN,
#     "item_code": "702611",
#     "item_name": "Crackers, soda, salted, per lb. (453.6 gm)",
#     "series_id": "APU0000702611",
#     "series_title": "Crackers, soda, salted, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M04",
#     "end_year": 2026,
#     "footnote_codes": NaN,
#     "item_code": "703111",
#     "item_name": "Ground chuck, 100% beef, per lb. (453.6 gm)",
#     "series_id": "APU0000703111",
#     "series_title": "Ground chuck, 100% beef, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1984,
#     "end_period": "M04",
#     "end_year": 2026,
#     "footnote_codes": NaN,
#     "item_code": "703112",
#     "item_name": "Ground beef, 100% beef, per lb. (453.6 gm)",
#     "series_id": "APU0000703112",
#     "series_title": "Ground beef, 100% beef, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1991,
#     "end_period": "M04",
#     "end_year": 2026,
#     "footnote_codes": NaN,
#     "item_code": "703113",
#     "item_name": "Ground beef, lean and extra lean, per lb. (453.6 gm)",
#     "series_id": "APU0000703113",
#     "series_title": "Ground beef, lean and extra lean, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M08",
#     "end_year": 1996,
#     "footnote_codes": NaN,
#     "item_code": "703211",
#     "item_name": "Chuck roast, USDA Choice, bone-in, per lb. (453.6 gm)",
#     "series_id": "APU0000703211",
#     "series_title": "Chuck roast, USDA Choice, bone-in, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1991,
#     "end_period": "M10",
#     "end_year": 2025,
#     "footnote_codes": NaN,
#     "item_code": "703212",
#     "item_name": "Chuck roast, graded and ungraded, excluding USDA Prime and Choice, per lb. (453.6 gm)",
#     "series_id": "APU0000703212",
#     "series_title": "Chuck roast, graded and ungraded, excluding USDA Prime and Choice, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1989,
#     "end_period": "M04",
#     "end_year": 2026,
#     "footnote_codes": NaN,
#     "item_code": "703213",
#     "item_name": "Chuck roast, USDA Choice, boneless, per lb. (453.6 gm)",
#     "series_id": "APU0000703213",
#     "series_title": "Chuck roast, USDA Choice, boneless, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M04",
#     "end_year": 2026,
#     "footnote_codes": NaN,
#     "item_code": "703311",
#     "item_name": "Round roast, USDA Choice, boneless, per lb. (453.6 gm)",
#     "series_id": "APU0000703311",
#     "series_title": "Round roast, USDA Choice, boneless, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1991,
#     "end_period": "M07",
#     "end_year": 2014,
#     "footnote_codes": NaN,
#     "item_code": "703312",
#     "item_name": "Round roast, graded and ungraded, excluding USDA Prime and Choice, per lb. (453.6 gm)",
#     "series_id": "APU0000703312",
#     "series_title": "Round roast, graded and ungraded, excluding USDA Prime and Choice, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M12",
#     "end_year": 1997,
#     "footnote_codes": NaN,
#     "item_code": "703411",
#     "item_name": "Rib roast, USDA Choice, bone-in, per lb. (453.6 gm)",
#     "series_id": "APU0000703411",
#     "series_title": "Rib roast, USDA Choice, bone-in, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M05",
#     "end_year": 1987,
#     "footnote_codes": NaN,
#     "item_code": "703421",
#     "item_name": "Steak, chuck, U.S. choice, bone-in (cost per pound/453.6 grams)",
#     "series_id": "APU0000703421",
#     "series_title": "Steak, chuck, U.S. choice, bone-in (cost per pound/453.6 grams) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M04",
#     "end_year": 2002,
#     "footnote_codes": NaN,
#     "item_code": "703422",
#     "item_name": "Steak, T-Bone, USDA Choice, bone-in, per lb. (453.6 gm)",
#     "series_id": "APU0000703422",
#     "series_title": "Steak, T-Bone, USDA Choice, bone-in, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M12",
#     "end_year": 1986,
#     "footnote_codes": NaN,
#     "item_code": "703423",
#     "item_name": "Steak, porterhouse, U.S. choice, bone-in (cost per pound/453.6 grams)",
#     "series_id": "APU0000703423",
#     "series_title": "Steak, porterhouse, U.S. choice, bone-in (cost per pound/453.6 grams) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1991,
#     "end_period": "M10",
#     "end_year": 2001,
#     "footnote_codes": NaN,
#     "item_code": "703425",
#     "item_name": "Steak, rib eye, USDA Choice, boneless, per lb. (453.6 gm)",
#     "series_id": "APU0000703425",
#     "series_title": "Steak, rib eye, USDA Choice, boneless, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1991,
#     "end_period": "M05",
#     "end_year": 2011,
#     "footnote_codes": NaN,
#     "item_code": "703431",
#     "item_name": "Short ribs, any primal source, bone-in, per lb. (453.6 gm)",
#     "series_id": "APU0000703431",
#     "series_title": "Short ribs, any primal source, bone-in, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1991,
#     "end_period": "M04",
#     "end_year": 2026,
#     "footnote_codes": NaN,
#     "item_code": "703432",
#     "item_name": "Beef for stew, boneless, per lb. (453.6 gm)",
#     "series_id": "APU0000703432",
#     "series_title": "Beef for stew, boneless, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M04",
#     "end_year": 2026,
#     "footnote_codes": NaN,
#     "item_code": "703511",
#     "item_name": "Steak, round, USDA Choice, boneless, per lb. (453.6 gm)",
#     "series_id": "APU0000703511",
#     "series_title": "Steak, round, USDA Choice, boneless, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1991,
#     "end_period": "M04",
#     "end_year": 2026,
#     "footnote_codes": NaN,
#     "item_code": "703512",
#     "item_name": "Steak, round, graded and ungraded, excluding USDA Prime and Choice, per lb. (453.6 gm)",
#     "series_id": "APU0000703512",
#     "series_title": "Steak, round, graded and ungraded, excluding USDA Prime and Choice, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M04",
#     "end_year": 1994,
#     "footnote_codes": NaN,
#     "item_code": "703611",
#     "item_name": "Steak, sirloin, USDA Choice, bone-in, per lb. (453.6 gm)",
#     "series_id": "APU0000703611",
#     "series_title": "Steak, sirloin, USDA Choice, bone-in, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1991,
#     "end_period": "M03",
#     "end_year": 2018,
#     "footnote_codes": NaN,
#     "item_code": "703612",
#     "item_name": "Steak, sirloin, graded and ungraded, excluding USDA Prime and Choice, per lb. (453.6 gm)",
#     "series_id": "APU0000703612",
#     "series_title": "Steak, sirloin, graded and ungraded, excluding USDA Prime and Choice, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1989,
#     "end_period": "M04",
#     "end_year": 2026,
#     "footnote_codes": NaN,
#     "item_code": "703613",
#     "item_name": "Steak, sirloin, USDA Choice, boneless, per lb. (453.6 gm)",
#     "series_id": "APU0000703613",
#     "series_title": "Steak, sirloin, USDA Choice, boneless, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M04",
#     "end_year": 2026,
#     "footnote_codes": NaN,
#     "item_code": "704111",
#     "item_name": "Bacon, sliced, per lb. (453.6 gm)",
#     "series_id": "APU0000704111",
#     "series_title": "Bacon, sliced, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M04",
#     "end_year": 2026,
#     "footnote_codes": NaN,
#     "item_code": "704211",
#     "item_name": "Chops, center cut, bone-in, per lb. (453.6 gm)",
#     "series_id": "APU0000704211",
#     "series_title": "Chops, center cut, bone-in, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M07",
#     "begin_year": 1995,
#     "end_period": "M04",
#     "end_year": 2026,
#     "footnote_codes": NaN,
#     "item_code": "704212",
#     "item_name": "Chops, boneless, per lb. (453.6 gm)",
#     "series_id": "APU0000704212",
#     "series_title": "Chops, boneless, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M06",
#     "end_year": 2016,
#     "footnote_codes": NaN,
#     "item_code": "704311",
#     "item_name": "Ham, rump or shank half, bone-in, smoked,per lb. (453.6 gm)",
#     "series_id": "APU0000704311",
#     "series_title": "Ham, rump or shank half, bone-in, smoked,per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1991,
#     "end_period": "M04",
#     "end_year": 2026,
#     "footnote_codes": NaN,
#     "item_code": "704312",
#     "item_name": "Ham, boneless, excluding canned, per lb. (453.6 gm)",
#     "series_id": "APU0000704312",
#     "series_title": "Ham, boneless, excluding canned, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M03",
#     "end_year": 1983,
#     "footnote_codes": NaN,
#     "item_code": "704313",
#     "item_name": "Ham, rump portion, bone-in, smoked (cost per pound/453.6 grams)",
#     "series_id": "APU0000704313",
#     "series_title": "Ham, rump portion, bone-in, smoked (cost per pound/453.6 grams) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M07",
#     "end_year": 1982,
#     "footnote_codes": NaN,
#     "item_code": "704314",
#     "item_name": "Ham, shank portion, bone-in, smoked (cost per pound/453.6 grams)",
#     "series_id": "APU0000704314",
#     "series_title": "Ham, shank portion, bone-in, smoked (cost per pound/453.6 grams) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M11",
#     "end_year": 1992,
#     "footnote_codes": NaN,
#     "item_code": "704321",
#     "item_name": "Ham, canned, 3 or 5 lbs, per lb. (453.6 gm)",
#     "series_id": "APU0000704321",
#     "series_title": "Ham, canned, 3 or 5 lbs, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M12",
#     "end_year": 1981,
#     "footnote_codes": NaN,
#     "item_code": "704411",
#     "item_name": "Pork shoulder roast, blade boston, bone-in (cost per pound/453.6 grams)",
#     "series_id": "APU0000704411",
#     "series_title": "Pork shoulder roast, blade boston, bone-in (cost per pound/453.6 grams) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M07",
#     "end_year": 1987,
#     "footnote_codes": NaN,
#     "item_code": "704412",
#     "item_name": "Pork sirloin roast, bone-in (cost per pound/453.6 grams)",
#     "series_id": "APU0000704412",
#     "series_title": "Pork sirloin roast, bone-in (cost per pound/453.6 grams) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M12",
#     "end_year": 1997,
#     "footnote_codes": NaN,
#     "item_code": "704413",
#     "item_name": "Shoulder picnic, bone-in, smoked, per lb. (453.6 gm)",
#     "series_id": "APU0000704413",
#     "series_title": "Shoulder picnic, bone-in, smoked, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M09",
#     "end_year": 2002,
#     "footnote_codes": NaN,
#     "item_code": "704421",
#     "item_name": "Sausage, fresh, loose, per lb. (453.6 gm)",
#     "series_id": "APU0000704421",
#     "series_title": "Sausage, fresh, loose, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M10",
#     "end_year": 2025,
#     "footnote_codes": NaN,
#     "item_code": "705111",
#     "item_name": "Frankfurters, all meat or all beef, per lb. (453.6 gm)",
#     "series_id": "APU0000705111",
#     "series_title": "Frankfurters, all meat or all beef, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M10",
#     "end_year": 2025,
#     "footnote_codes": NaN,
#     "item_code": "705121",
#     "item_name": "Bologna, all beef or mixed, per lb. (453.6 gm)",
#     "series_id": "APU0000705121",
#     "series_title": "Bologna, all beef or mixed, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M10",
#     "end_year": 1988,
#     "footnote_codes": NaN,
#     "item_code": "705141",
#     "item_name": "Beef liver (cost per pound/453.6 grams)",
#     "series_id": "APU0000705141",
#     "series_title": "Beef liver (cost per pound/453.6 grams) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1991,
#     "end_period": "M01",
#     "end_year": 1994,
#     "footnote_codes": NaN,
#     "item_code": "705142",
#     "item_name": "Lamb and mutton, bone-in, per lb. (453.6 gm)",
#     "series_id": "APU0000705142",
#     "series_title": "Lamb and mutton, bone-in, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M04",
#     "end_year": 2026,
#     "footnote_codes": NaN,
#     "item_code": "706111",
#     "item_name": "Chicken, fresh, whole, per lb. (453.6 gm)",
#     "series_id": "APU0000706111",
#     "series_title": "Chicken, fresh, whole, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M10",
#     "end_year": 2011,
#     "footnote_codes": NaN,
#     "item_code": "706211",
#     "item_name": "Chicken breast, bone-in, per lb. (453.6 gm)",
#     "series_id": "APU0000706211",
#     "series_title": "Chicken breast, bone-in, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M04",
#     "end_year": 2026,
#     "footnote_codes": NaN,
#     "item_code": "706212",
#     "item_name": "Chicken legs, bone-in, per lb. (453.6 gm)",
#     "series_id": "APU0000706212",
#     "series_title": "Chicken legs, bone-in, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M10",
#     "end_year": 2025,
#     "footnote_codes": NaN,
#     "item_code": "706311",
#     "item_name": "Turkey, frozen, whole, per lb. (453.6 gm)",
#     "series_id": "APU0000706311",
#     "series_title": "Turkey, frozen, whole, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M09",
#     "end_year": 2017,
#     "footnote_codes": NaN,
#     "item_code": "707111",
#     "item_name": "Tuna, light, chunk, per lb. (453.6 gm)",
#     "series_id": "APU0000707111",
#     "series_title": "Tuna, light, chunk, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M04",
#     "end_year": 2026,
#     "footnote_codes": NaN,
#     "item_code": "708111",
#     "item_name": "Eggs, grade A, large, per doz.",
#     "series_id": "APU0000708111",
#     "series_title": "Eggs, grade A, large, per doz. in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M10",
#     "end_year": 2025,
#     "footnote_codes": NaN,
#     "item_code": "708112",
#     "item_name": "Eggs, grade AA, large, per doz.",
#     "series_id": "APU0000708112",
#     "series_title": "Eggs, grade AA, large, per doz. in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M12",
#     "end_year": 1997,
#     "footnote_codes": NaN,
#     "item_code": "709111",
#     "item_name": "Milk, fresh, whole, fortified, per 1/2 gal. (1.9 lit)",
#     "series_id": "APU0000709111",
#     "series_title": "Milk, fresh, whole, fortified, per 1/2 gal. (1.9 lit) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M07",
#     "begin_year": 1995,
#     "end_period": "M04",
#     "end_year": 2026,
#     "footnote_codes": NaN,
#     "item_code": "709112",
#     "item_name": "Milk, fresh, whole, fortified, per gal. (3.8 lit)",
#     "series_id": "APU0000709112",
#     "series_title": "Milk, fresh, whole, fortified, per gal. (3.8 lit) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M05",
#     "end_year": 1986,
#     "footnote_codes": NaN,
#     "item_code": "709211",
#     "item_name": "Milk, fresh, skim (cost per one-half gallon/1.9 liters)",
#     "series_id": "APU0000709211",
#     "series_title": "Milk, fresh, skim (cost per one-half gallon/1.9 liters) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M09",
#     "end_year": 1992,
#     "footnote_codes": NaN,
#     "item_code": "709212",
#     "item_name": "Milk, fresh, low fat, per 1/2 gal. (1.9 lit)",
#     "series_id": "APU0000709212",
#     "series_title": "Milk, fresh, low fat, per 1/2 gal. (1.9 lit) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M07",
#     "begin_year": 1995,
#     "end_period": "M10",
#     "end_year": 2002,
#     "footnote_codes": NaN,
#     "item_code": "709213",
#     "item_name": "Milk, fresh, low fat, per gal. (3.8 lit)",
#     "series_id": "APU0000709213",
#     "series_title": "Milk, fresh, low fat, per gal. (3.8 lit) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M04",
#     "end_year": 2012,
#     "footnote_codes": NaN,
#     "item_code": "710111",
#     "item_name": "Butter, salted, grade AA, stick, per lb. (453.6 gm)",
#     "series_id": "APU0000710111",
#     "series_title": "Butter, salted, grade AA, stick, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M03",
#     "end_year": 2003,
#     "footnote_codes": NaN,
#     "item_code": "710122",
#     "item_name": "Yogurt, natural, fruit flavored, per 8 oz. (226.8 gm)",
#     "series_id": "APU0000710122",
#     "series_title": "Yogurt, natural, fruit flavored, per 8 oz. (226.8 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1984,
#     "end_period": "M04",
#     "end_year": 2026,
#     "footnote_codes": NaN,
#     "item_code": "710211",
#     "item_name": "American processed cheese, per lb. (453.6 gm)",
#     "series_id": "APU0000710211",
#     "series_title": "American processed cheese, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1984,
#     "end_period": "M04",
#     "end_year": 2026,
#     "footnote_codes": NaN,
#     "item_code": "710212",
#     "item_name": "Cheddar cheese, natural, per lb. (453.6 gm)",
#     "series_id": "APU0000710212",
#     "series_title": "Cheddar cheese, natural, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M04",
#     "end_year": 2026,
#     "footnote_codes": NaN,
#     "item_code": "710411",
#     "item_name": "Ice cream, prepackaged, bulk, regular, per 1/2 gal. (1.9 lit)",
#     "series_id": "APU0000710411",
#     "series_title": "Ice cream, prepackaged, bulk, regular, per 1/2 gal. (1.9 lit) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M10",
#     "end_year": 2017,
#     "footnote_codes": NaN,
#     "item_code": "711111",
#     "item_name": "Apples, Red Delicious, per lb. (453.6 gm)",
#     "series_id": "APU0000711111",
#     "series_title": "Apples, Red Delicious, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M04",
#     "end_year": 2026,
#     "footnote_codes": NaN,
#     "item_code": "711211",
#     "item_name": "Bananas, per lb. (453.6 gm)",
#     "series_id": "APU0000711211",
#     "series_title": "Bananas, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M04",
#     "end_year": 2026,
#     "footnote_codes": NaN,
#     "item_code": "711311",
#     "item_name": "Oranges, Navel, per lb. (453.6 gm)",
#     "series_id": "APU0000711311",
#     "series_title": "Oranges, Navel, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M06",
#     "begin_year": 1980,
#     "end_period": "M08",
#     "end_year": 2013,
#     "footnote_codes": NaN,
#     "item_code": "711312",
#     "item_name": "Oranges, Valencia, per lb. (453.6 gm)",
#     "series_id": "APU0000711312",
#     "series_title": "Oranges, Valencia, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M04",
#     "end_year": 2026,
#     "footnote_codes": NaN,
#     "item_code": "711411",
#     "item_name": "Grapefruit, per lb. (453.6 gm)",
#     "series_id": "APU0000711411",
#     "series_title": "Grapefruit, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M04",
#     "end_year": 2026,
#     "footnote_codes": NaN,
#     "item_code": "711412",
#     "item_name": "Lemons, per lb. (453.6 gm)",
#     "series_id": "APU0000711412",
#     "series_title": "Lemons, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M10",
#     "end_year": 2025,
#     "footnote_codes": NaN,
#     "item_code": "711413",
#     "item_name": "Pears, Anjou, per lb. (453.6 gm)",
#     "series_id": "APU0000711413",
#     "series_title": "Pears, Anjou, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M06",
#     "begin_year": 1980,
#     "end_period": "M10",
#     "end_year": 2025,
#     "footnote_codes": NaN,
#     "item_code": "711414",
#     "item_name": "Peaches, per lb. (453.6 gm)",
#     "series_id": "APU0000711414",
#     "series_title": "Peaches, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M04",
#     "begin_year": 1980,
#     "end_period": "M04",
#     "end_year": 2026,
#     "footnote_codes": NaN,
#     "item_code": "711415",
#     "item_name": "Strawberries, dry pint, per 12 oz. (340.2 gm)",
#     "series_id": "APU0000711415",
#     "series_title": "Strawberries, dry pint, per 12 oz. (340.2 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M12",
#     "end_year": 1987,
#     "footnote_codes": NaN,
#     "item_code": "711416",
#     "item_name": "Grapes, Emperor or Tokay (cost per pound/453.6 grams)",
#     "series_id": "APU0000711416",
#     "series_title": "Grapes, Emperor or Tokay (cost per pound/453.6 grams) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M07",
#     "begin_year": 1980,
#     "end_period": "M10",
#     "end_year": 2025,
#     "footnote_codes": NaN,
#     "item_code": "711417",
#     "item_name": "Grapes, Thompson Seedless, per lb. (453.6 gm)",
#     "series_id": "APU0000711417",
#     "series_title": "Grapes, Thompson Seedless, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M06",
#     "begin_year": 1980,
#     "end_period": "M10",
#     "end_year": 2025,
#     "footnote_codes": NaN,
#     "item_code": "711418",
#     "item_name": "Cherries, per lb. (453.6 gm)",
#     "series_id": "APU0000711418",
#     "series_title": "Cherries, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M02",
#     "end_year": 1986,
#     "footnote_codes": NaN,
#     "item_code": "712111",
#     "item_name": "Potatoes, white (cost per pound/453.6 grams)",
#     "series_id": "APU0000712111",
#     "series_title": "Potatoes, white (cost per pound/453.6 grams) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M03",
#     "begin_year": 1986,
#     "end_period": "M04",
#     "end_year": 2026,
#     "footnote_codes": NaN,
#     "item_code": "712112",
#     "item_name": "Potatoes, white, per lb. (453.6 gm)",
#     "series_id": "APU0000712112",
#     "series_title": "Potatoes, white, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M04",
#     "end_year": 2026,
#     "footnote_codes": NaN,
#     "item_code": "712211",
#     "item_name": "Lettuce, iceberg, per lb. (453.6 gm)",
#     "series_id": "APU0000712211",
#     "series_title": "Lettuce, iceberg, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M04",
#     "end_year": 2026,
#     "footnote_codes": NaN,
#     "item_code": "712311",
#     "item_name": "Tomatoes, field grown, per lb. (453.6 gm)",
#     "series_id": "APU0000712311",
#     "series_title": "Tomatoes, field grown, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M10",
#     "end_year": 2012,
#     "footnote_codes": NaN,
#     "item_code": "712401",
#     "item_name": "Cabbage, per lb. (453.6 gm)",
#     "series_id": "APU0000712401",
#     "series_title": "Cabbage, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M10",
#     "end_year": 2012,
#     "footnote_codes": NaN,
#     "item_code": "712402",
#     "item_name": "Celery, per lb. (453.6 gm)",
#     "series_id": "APU0000712402",
#     "series_title": "Celery, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M03",
#     "end_year": 2014,
#     "footnote_codes": NaN,
#     "item_code": "712403",
#     "item_name": "Carrots, short trimmed and topped, per lb. (453.6 gm)",
#     "series_id": "APU0000712403",
#     "series_title": "Carrots, short trimmed and topped, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M12",
#     "end_year": 1997,
#     "footnote_codes": NaN,
#     "item_code": "712404",
#     "item_name": "Onions, dry yellow, per lb. (453.6 gm)",
#     "series_id": "APU0000712404",
#     "series_title": "Onions, dry yellow, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M07",
#     "end_year": 1987,
#     "footnote_codes": NaN,
#     "item_code": "712405",
#     "item_name": "Onions, green scallions (cost per pound/453.6 grams)",
#     "series_id": "APU0000712405",
#     "series_title": "Onions, green scallions (cost per pound/453.6 grams) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M10",
#     "end_year": 2025,
#     "footnote_codes": NaN,
#     "item_code": "712406",
#     "item_name": "Peppers, sweet, per lb. (453.6 gm)",
#     "series_id": "APU0000712406",
#     "series_title": "Peppers, sweet, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M04",
#     "begin_year": 1980,
#     "end_period": "M06",
#     "end_year": 1988,
#     "footnote_codes": NaN,
#     "item_code": "712407",
#     "item_name": "Corn on the cob, per lb. (453.6 gm)",
#     "series_id": "APU0000712407",
#     "series_title": "Corn on the cob, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M02",
#     "end_year": 1989,
#     "footnote_codes": NaN,
#     "item_code": "712408",
#     "item_name": "Radishes (cost per pound/453.6 grams)",
#     "series_id": "APU0000712408",
#     "series_title": "Radishes (cost per pound/453.6 grams) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M04",
#     "end_year": 2000,
#     "footnote_codes": NaN,
#     "item_code": "712409",
#     "item_name": "Cucumbers, per lb. (453.6 gm)",
#     "series_id": "APU0000712409",
#     "series_title": "Cucumbers, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M02",
#     "end_year": 1989,
#     "footnote_codes": NaN,
#     "item_code": "712410",
#     "item_name": "Beans, green, snap (cost per pound/453.6 grams)",
#     "series_id": "APU0000712410",
#     "series_title": "Beans, green, snap (cost per pound/453.6 grams) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M01",
#     "end_year": 1986,
#     "footnote_codes": NaN,
#     "item_code": "712411",
#     "item_name": "Mushrooms (cost per pound/453.6 grams)",
#     "series_id": "APU0000712411",
#     "series_title": "Mushrooms (cost per pound/453.6 grams) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M07",
#     "begin_year": 1995,
#     "end_period": "M10",
#     "end_year": 2025,
#     "footnote_codes": NaN,
#     "item_code": "712412",
#     "item_name": "Broccoli, per lb. (453.6 gm)",
#     "series_id": "APU0000712412",
#     "series_title": "Broccoli, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M04",
#     "end_year": 2026,
#     "footnote_codes": NaN,
#     "item_code": "713111",
#     "item_name": "Orange juice, frozen concentrate, 12 oz. can, per 16 oz. (473.2 ml)",
#     "series_id": "APU0000713111",
#     "series_title": "Orange juice, frozen concentrate, 12 oz. can, per 16 oz. (473.2 ml) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M07",
#     "begin_year": 1995,
#     "end_period": "M12",
#     "end_year": 1997,
#     "footnote_codes": NaN,
#     "item_code": "713311",
#     "item_name": "Apple Sauce, any variety, all sizes, per lb. (453.6 gm)",
#     "series_id": "APU0000713311",
#     "series_title": "Apple Sauce, any variety, all sizes, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M07",
#     "begin_year": 1995,
#     "end_period": "M12",
#     "end_year": 1997,
#     "footnote_codes": NaN,
#     "item_code": "713312",
#     "item_name": "Peaches, any variety, all sizes, per lb. (453.6 gm)",
#     "series_id": "APU0000713312",
#     "series_title": "Peaches, any variety, all sizes, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M02",
#     "end_year": 2005,
#     "footnote_codes": NaN,
#     "item_code": "714111",
#     "item_name": "Potatoes, frozen, French fried, per lb. (453.6 gm)",
#     "series_id": "APU0000714111",
#     "series_title": "Potatoes, frozen, French fried, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M07",
#     "begin_year": 1995,
#     "end_period": "M04",
#     "end_year": 2026,
#     "footnote_codes": NaN,
#     "item_code": "714221",
#     "item_name": "Corn, canned, any style, all sizes, per lb. (453.6 gm)",
#     "series_id": "APU0000714221",
#     "series_title": "Corn, canned, any style, all sizes, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M02",
#     "end_year": 1988,
#     "footnote_codes": NaN,
#     "item_code": "714231",
#     "item_name": "Tomatoes, canned, whole, per lb. (453.6 gm)",
#     "series_id": "APU0000714231",
#     "series_title": "Tomatoes, canned, whole, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M07",
#     "begin_year": 1995,
#     "end_period": "M12",
#     "end_year": 1997,
#     "footnote_codes": NaN,
#     "item_code": "714232",
#     "item_name": "Tomatoes, canned, any type, all sizes,  per lb. (453.6 gm)",
#     "series_id": "APU0000714232",
#     "series_title": "Tomatoes, canned, any type, all sizes,  per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M07",
#     "begin_year": 1995,
#     "end_period": "M04",
#     "end_year": 2026,
#     "footnote_codes": NaN,
#     "item_code": "714233",
#     "item_name": "Beans, dried, any type, all sizes, per lb. (453.6 gm)",
#     "series_id": "APU0000714233",
#     "series_title": "Beans, dried, any type, all sizes, per lb. (453.6 gm) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M11",
#     "end_year": 1986,
#     "footnote_codes": NaN,
#     "item_code": "715111",
#     "item_name": "Hard candy, solid (cost per pound/453.6 grams)",
#     "series_id": "APU0000715111",
#     "series_title": "Hard candy, solid (cost per pound/453.6 grams) in U.S. city average, average price, not seasonally adjusted"
#   },
#   {
#     "area_code": "0000",
#     "area_name": "U.S. city average",
#     "begin_period": "M01",
#     "begin_year": 1980,
#     "end_period": "M04",
#     "end_year": 2026,
#     "footnote_codes": NaN,
#     "item_code": "715211",
#     "item_name": "Sugar, white, all sizes, per lb. (453.6 gm)",
#     "series_id": "APU0000715211",
# ...
#         "value": "2.934"
#       },
#       {
#         "period": "M02",
#         "value": "3.001"
#       },
#       {
#         "period": "M03",
#         "value": "3.049"
#       },
#       {
#         "period": "M04",
#         "value": "3.069"
#       },
#       {
#         "period": "M05",
#         "value": "3.125"
#       },
#       {
#         "period": "M06",
#         "value": "3.061"
#       },
#       {
#         "period": "M07",
#         "value": "3.103"
#       },
#       {
#         "period": "M08",
#         "value": "3.094"
#       },
#       {
#         "period": "M09",
#         "value": "3.142"
#       },
#       {
#         "period": "M10",
#         "value": "3.092"
#       },
#       {
#         "period": "M11",
#         "value": "3.109"
#       },
#       {
#         "period": "M12",
#         "value": "3.068"
#       }
#     ],
#     "2008": [
#       {
#         "period": "M01",
#         "value": "3.129"
#       },
#       {
#         "period": "M02",
#         "value": "3.161"
#       },
#       {
#         "period": "M03",
#         "value": "3.157"
#       },
#       {
#         "period": "M04",
#         "value": "3.154"
#       },
#       {
#         "period": "M05",
#         "value": "3.176"
#       },
#       {
#         "period": "M06",
#         "value": "3.198"
#       },
#       {
#         "period": "M07",
#         "value": "3.228"
#       },
#       {
#         "period": "M08",
#         "value": "3.314"
#       },
#       {
#         "period": "M09",
#         "value": "3.340"
#       },
#       {
#         "period": "M10",
#         "value": "3.418"
#       },
#       {
#         "period": "M11",
#         "value": "3.434"
#       },
#       {
#         "period": "M12",
#         "value": "3.435"
#       }
#     ],
#     "2009": [
#       {
#         "period": "M01",
#         "value": "3.426"
#       },
#       {
#         "period": "M02",
#         "value": "3.440"
#       },
#       {
#         "period": "M03",
#         "value": "3.355"
#       },
#       {
#         "period": "M04",
#         "value": "3.332"
#       },
#       {
#         "period": "M05",
#         "value": "3.427"
#       },
#       {
#         "period": "M06",
#         "value": "3.469"
#       },
#       {
#         "period": "M07",
#         "value": "3.304"
#       },
#       {
#         "period": "M08",
#         "value": "3.452"
#       },
#       {
#         "period": "M09",
#         "value": "3.397"
#         "value": "6.479"
#       },
#       {
#         "period": "M05",
#         "value": "6.546"
#       },
#       {
#         "period": "M06",
#         "value": "6.492"
#       },
#       {
#         "period": "M07",
#         "value": "6.580"
#       },
#       {
#         "period": "M08",
#         "value": "6.512"
#       },
#       {
#         "period": "M09",
#         "value": "6.624"
#       },
#       {
#         "period": "M10",
#         "value": "6.680"
#       },
#       {
#         "period": "M11",
#         "value": "6.227"
#       },
#       {
#         "period": "M12",
#         "value": "6.386"
#       }
#     ],
#     "2023": [
#       {
#         "period": "M01",
#         "value": "6.393"
#       },
#       {
#         "period": "M02",
#         "value": "6.427"
#       },
#       {
#         "period": "M03",
#         "value": "6.354"
#       },
#       {
#         "period": "M04",
#         "value": "6.579"
#       },
#       {
#         "period": "M05",
#         "value": "6.697"
#       },
#       {
#         "period": "M06",
#         "value": "6.681"
#       },
#       {
#         "period": "M07",
#         "value": "6.851"
#       },
#       {
#         "period": "M08",
#         "value": "6.947"
#       },
#       {
#         "period": "M09",
#         "value": "6.884"
#       },
#       {
#         "period": "M10",
#         "value": "6.991"
#       },
#       {
#         "period": "M11",
#         "value": "6.731"
#       },
#       {
#         "period": "M12",
#         "value": "6.674"
#       }
#     ],
#     "2024": [
#       {
#         "period": "M01",
#         "value": "6.778"
#       },
#       {
#         "period": "M02",
#         "value": "6.651"
#       },
#       {
#         "period": "M03",
#         "value": "6.734"
#       },
#       {
#         "period": "M04",
#         "value": "6.809"
#       },
#       {
#         "period": "M05",
#         "value": "6.847"
#       },
#       {
#         "period": "M06",
#         "value": "6.893"
#       },
#       {
#         "period": "M07",
#         "value": "7.169"
#       },
#       {
#         "period": "M08",
#         "value": "6.918"
#       },
#       {
#         "period": "M09",
#         "value": "7.223"
#       },
#       {
#         "period": "M10",
#         "value": "7.220"
#       },
#       {
#         "period": "M11",
#         "value": "6.977"
#       },
#       {
#         "period": "M12",
#         "value": "7.124"
#       }
#     ],
#     "2025": [
#       {
#         "period": "M01",
#         "value": "7.110"
#       },
#       {
#         "period": "M02",
#         "value": "7.244"
#       },
#       {
#         "period": "M03",
#         "value": "7.476"
#       },
#       {
#         "period": "M04",
#         "value": "7.551"
#       },
#       {
#         "period": "M05",
#         "value": "7.688"
#       },
#       {
#         "period": "M06",
#         "value": "7.672"
#       },
#       {
#         "period": "M07",
#         "value": "8.035"
#       },
#       {
#         "period": "M08",
#         "value": "7.950"
#       },
#       {
#         "period": "M09",
#         "value": "8.182"
#       },
#       {
#         "period": "M10",
#         "value": "-"
#       },
#       {
#         "period": "M11",
#         "value": "8.232"
#       },
#       {
#         "period": "M12",
#         "value": "8.254"
#       }
#     ],
#     "2026": [
#       {
#         "period": "M01",
#         "value": "8.191"
#       },
#       {
#         "period": "M02",
#         "value": "8.338"
#       },
#       {
#         "period": "M03",
#         "value": "8.200"
#       },
#       {
#         "period": "M04",
#         "value": "8.512"
#       }
#     ]
#   },
#   "item": "Ground beef, lean and extra lean, per lb. (453.6 gm)",
#   "series_id": "APU0000703113"
# }
